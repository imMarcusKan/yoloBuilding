# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14740, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 14740 (delta 53), reused 66 (delta 38), pack-reused 14655
# Receiving objects: 100% (14740/14740), 13.83 MiB | 30.46 MiB/s, done.
# Resolving deltas: 100% (10136/10136), done.
# /content/yolov5
#      |████████████████████████████████| 182 kB 5.0 MB/s
#      |████████████████████████████████| 62 kB 1.6 MB/s
#      |████████████████████████████████| 1.6 MB 56.3 MB/s

# %%
import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-42-g5545ff3 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/78.2 GB disk)

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/yoloBuilding/flow.ymal --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yoloBuilding/flow.ymal, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-42-g5545ff3 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !zip -r /content/myModels.zip /content/yolov5/runs/train/exp
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/train_batch2.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp/results.png (deflated 8%)
#   adding: content/yolov5/runs/train/exp/R_curve.png (deflated 10%)
#   adding: content/yolov5/runs/train/exp/results.csv (deflated 83%)
#   adding: content/yolov5/runs/train/exp/val_batch2_pred.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp/F1_curve.png (deflated 8%)
#   adding: content/yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/best.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 9%)
# ...
